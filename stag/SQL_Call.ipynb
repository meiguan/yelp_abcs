# %%
import os
import sys
import datetime
import requests
import urllib.request
import json
import pandas as pd
import psycopg2
from sqlalchemy import create_engine

sys.path.append('../')
from envir import config

# %%
engine = create_engine('postgresql+psycopg2:///yelp_abcs')
con = engine.connect()

# %%
pd.read_sql('select * from stag.ny_zipcodes', engine)
# Out:
#       county_name  state_fips  county_code  county_fips zip_code
# 0          Albany          36            1        36001    12046
# 1          Albany          36            1        36001    12083
# 2          Albany          36            1        36001    12085
# 3          Albany          36            1        36001    12201
# 4          Albany          36            1        36001    12203
# 5          Albany          36            1        36001    12055
# 6          Albany          36            1        36001    12204
# 7          Albany          36            1        36001    12023
# 8          Albany          36            1        36001    12087
# 9          Albany          36            1        36001    12205
# 10         Albany          36            1        36001    12110
# 11         Albany          36            1        36001    12009
# 12         Albany          36            1        36001    12202
# ...
