# %% [markdown]
# ### cleaning yelp academic buiness dataset for restaurants and by categories 1 hot
#
# - subset for Las Vegas and Toronto
# - Restaurants and categories of restaurants (i.e. Italian, Dim Sum, etc.)
# - save the dataset to clean schema and name appropriately

# %%
import os
import sys
import datetime
import requests
import urllib.request
import json
import pandas as pd
import psycopg2
from sqlalchemy import create_engine

sys.path.append('../')
from envir import config

# %%
engine = create_engine('postgresql+psycopg2:///yelp_abcs')
con = engine.connect
pd.read_sql('select * from stag.yelp_academic_business limit 10', engine)
# Out:
#    index             business_id                             name  \
# 0      0  1SWheh84yJXfytovILXOAQ       Arizona Biltmore Golf Club
# 1      1  QXAEGFB4oINsVuTFxEYKFQ       Emerald Chinese Restaurant
# 2      2  gnKjwL_1w79qoiV3IC_xQQ      Musashi Japanese Restaurant
# 3      3  xvX2CttrVhyG2z1dFg_0xw  Farmers Insurance - Paul Lorenz
# 4      4  HhyxOkGAM07SRYtlQ4wMFQ              Queen City Plumbing
# 5      5  68dUKd8_8liJ7in4aWOSEA                    The UPS Store
# 6      6  5JucpCfHZltJh5r1JabjDg                 Edgeworxx Studio
# 7      7  gbQN7vr_caG_A1ugSmGhWg                        Supercuts
# 8      8  Y6iyemLX_oylRpnr38vgMA          Vita Bella Fine Day Spa
# 9      9  4GBVPIYRvzGh4K4TkRQ_rw              Options Salon & Spa
#
#                                              address           city state  \
# 0                        2818 E Camino Acequia Drive        Phoenix    AZ
# 1                               30 Eglinton Avenue W    Mississauga    ON
# ...
