# %%
import os
import sys
import csv
import pandas as pd
import psycopg2
from sqlalchemy import create_engine
from fuzzywuzzy import fuzz 
from fuzzywuzzy import process 

sys.path.append('../')
from envir import config

# %% [markdown]
# This notebook uses the csv file from running the script named: 'fuzzy_match_business_names.py'
#
#
# #### connect & load data

# %%
engine = create_engine('postgresql+psycopg2:///yelp_abcs')
con = engine.connect

# %%
yelp = pd.read_sql("select * from stag.yelp_academic_business where state in ('ON', 'NV');", con=engine )
vegas = pd.read_sql("select * from clean.clean_vegas_violations;", con=engine)
toronto = pd.read_sql("select * from clean.toronto_inspections_cleaned;", con=engine)

# %%
yelp2 = yelp.loc[yelp['categories'].str.contains("Restaurant")==True][['business_id',
                                                                       'name', 'address']].copy()

yelp2.reset_index(inplace=True)

# %%
yelp2[yelp2.business_id=='EBHzEtuOJz474NwRQFqJbg']
# Out:
#                   business_id                              yelp_name_address
# 18159  EBHzEtuOJz474NwRQFqJbg  Popeyes Louisiana Kitchen 1955 Queen Street E

# %% [markdown]
# #### prep for concat / append tables

# %%
len(toronto) + len(vegas)
# Out:
# 264386

# %%
vegas.drop(columns=['index'], inplace=True)

# %%
violations = vegas.append(toronto, ignore_index=True, sort=True)

# %% [markdown]
# #### get unique business names from violations

# %%
fuzz_match = pd.read_csv(config.shared+'fuzzy_biz_names80.csv')

# %%
fuzz_match[(fuzz_match.yelp_name_address == fuzz_match.violations_name_address) & (fuzz_match.match_score < 100)]
# Out:
# Empty DataFrame
# Columns: [yelp_name_address, violations_name_address, match_score]
# Index: []

# %%
fuzz_match[(fuzz_match.yelp_name_address != fuzz_match.violations_name_address) & (fuzz_match.match_score == 100)]
# Out:
#                             yelp_name_address  \
# 106    D-Spot Dessert Cafe 1060 The Queensway
# 121               Kimchi House 586 Bloor St W
# 129       Brass Taps Pizza Pub 934 College St
# 243               Pho Vietnam 1280 Kennedy Rd
# 250       Las Tapatias 6132 W Charleston Blvd
# ...                                       ...
# 30864          5 Spice Dining 2826 Markham Rd
# 30889        C&C Supermarket 888 Don Mills Rd
# 30965           Pumpernickel's 101 College St
# 30987    Peter Piper Pizza 6081 S Eastern Ave
# 31019     Kobi Korean Restaurant 710 Yonge St
#
#                         violations_name_address  match_score
# 106    D SPOT DESSERT CAFE 1060 THE QUEENSWAY          100.0
# 121                 KIMCHI HOUSE 586 BLOOR ST W        100.0
# 129        BRASS TAPS PIZZA PUB 934 COLLEGE ST         100.0
# 243                PHO VIETNAM 1280 KENNEDY RD         100.0
# 250         LAS TAPATIAS 6132 W Charleston Blvd        100.0
# ...                                         ...          ...
# 30864          5 SPICE DINING  2826 MARKHAM RD         100.0
# 30889      C & C SUPERMARKET  888 DON MILLS RD         100.0
# 30965            PUMPERNICKEL'S 101 COLLEGE ST         100.0
# 30987      PETER PIPER PIZZA 6081 S EASTERN Ave        100.0
# 31019      KOBI KOREAN RESTAURANT 710 YONGE ST         100.0
#
# [649 rows x 3 columns]

# %%
fuzz_match.groupby(['yelp_name_address',
                    'violations_name_address'],as_index=False).size().sort_values(ascending=False)
# Out:
# yelp_name_address                                       violations_name_address
# Burger King 3401 E Tropicana Ave                        Burger King #2701 3401 E Tropicana Ave                       2
# Ravi Soups 322 Adelaide Street W                        RAVI'S SOUP 322 ADELAIDE ST W                                2
# Baja Fresh 8780 W Charleston Blvd, Ste 100              Baja Fresh 8780 W Charleston Blvd                            2
# Carl's Jr. 4901 W Craig Rd                              CARL'S JR #7073 4901 W Craig Rd                              2
# Pizza Pizza 260 Church Street                           PIZZA PIZZA 260 CHURCH ST                                    2
#                                                                                                                     ..
# Popeyes Louisiana Kitchen 150 Park Lawn Road            POPEYES LOUISIANA KITCHEN 150 PARK LAWN RD                   1
# Popeyes Louisiana Kitchen 1525 Dundas Street E, Unit 4  POPEYES LOUISIANA KITCHEN 275 DUNDAS ST W                    1
# Popeyes Louisiana Kitchen 181 Eglinton Avenue E         POPEYES LOUISIANA KITCHEN 181 EGLINTON AVE E                 1
# Popeyes Louisiana Kitchen 1955 Queen Street E           POPEYES LOUISIANA KITCHEN 1955 QUEEN ST E                    1
# #1 Hawaiian Barbecue 5905 S Eastern Ave, Ste 105        CHINA DRAGON/#1 HAWAIIAN BARBEQUE 5905 S EASTERN Ave -105    1
# Length: 8424, dtype: int64

# %%
fuzz_match.sort_values(['violations_name_address','match_score'], ascending=False, inplace=True)

# %%
fuzz_match.drop_duplicates(['violations_name_address'], inplace=True)

# %%
yelp2
# Out:
#                   business_id  \
# 0      QXAEGFB4oINsVuTFxEYKFQ
# 1      PZ-LZzSlhSe9utkQYU8pFg
# 2      tstimHoMcYbkSC4eBA1wEg
# 3      NDuUMJfrWk52RA-H-OtrpA
# 4      SP_YXIEwkFPPl_9anCYmpQ
# ...                       ...
# 22615  sVEE_Mp3EbWW1UIhfActVA
# 22616  lo8WwqKogC-kz4toRvkdUQ
# 22617  3HAPJH0Qoi8Ix6M9rUMfjg
# 22618  oS0CnUbyv0GUoD3L8_3UPQ
# 22619  h3QErqS3OZgLJ5Tb6-sLyQ
#
#                                        yelp_name_address
# 0        Emerald Chinese Restaurant 30 Eglinton Avenue W
# 1      Carluccio's Tivoli Gardens 1775 E Tropicana Av...
# 2      Maria's Mexican Restaurant & Bakery 6055 E Lak...
# 3                     Bolt Fresh Bar 1170 Queen Street W
# 4              The Steady Cafe & Bar 1051 Bloor Street W
# ...                                                  ...
# 22615            The King's Kitchen 9275 Hwy 48, Unit 11
# 22616                KOKO! Share Bar 81 Yorkville Avenue
# 22617                        Indian Hero 8920 Highway 50
# 22618                      Thai Fantasy 578 Yonge Street
# 22619                          Asia Hut 1450 Kingston Rd
#
# [22620 rows x 2 columns]

# %%
yelp2['yelp_name_address'] = yelp2['name'] + ' ' + yelp2['address']

# %%
yelp2.drop(columns=['name', 'address', 'index'], inplace=True)

# %%
violations['violations_name_address'] = violations['name'] + ' ' + violations['address']

# %%
fuzz_match.groupby(['violations_name_address'],as_index=False).size().sort_values(ascending=False)
# Out:
# violations_name_address
# iQ FOOD CO. 181 BAY ST                            1
# Gusto Pizza 1 BONIS AVE                           1
# HAMPTONS 440 S RAMPART Blvd 180                   1
# HAN BA TANG RESTAURANT 4862 YONGE ST              1
# HANA KOREA 45 BALDWIN ST                          1
#                                                  ..
# PTS GOLD 47 9050 W Post Rd                        1
# PUBLIC HOUSE @ LUXOR 3900 S LAS VEGAS Blvd        1
# PUBLICUS 1126 FREMONT St                          1
# PUCK N WINGS 5625 YONGE ST                        1
# #1 HAWAIIAN BARBECUE 7960 S RAINBOW Blvd 8000G    1
# Length: 7720, dtype: int64

# %%
matched = violations.merge(fuzz_match,
                           on='violations_name_address', how='inner').merge(yelp2,
                                                                              on='yelp_name_address', how='inner')

# %%
matched.columns
# Out:
# Index(['address', 'city', 'crucial', 'establishment_type', 'inspection_date',
#        'inspection_result', 'latitude', 'longitude', 'minor', 'name',
#        'significant', 'violations_desc', 'violations_name_address',
#        'yelp_name_address', 'match_score', 'business_id'],
#       dtype='object')

# %%
matched_ord = matched.reindex(columns=['business_id','city','inspection_date', 'name','establishment_type',
                                       'address','latitude', 'longitude','inspection_result',
                                       'violations_desc','minor','crucial','significant','violations_desc']).copy()

# %%
try:
    matched_ord.to_sql("violations_matched_yelp_id2", engine, schema="clean")
except:
    print('table already exists')

# %%
matched_ord.to_csv(config.shared+'violations_matched_yelp_id.csv')

# %%
len(violations)
# Out:
# 264386

# %%
len(matched_ord)
# Out:
# 122548

# %%
len(matched_ord)/len(violations)
# Out:
# 0.46351924837169894

# %%
matched_ord[matched_ord.city=='toronto'].groupby('business_id').count().sort_values('inspection_date', ascending=False).head(20)
# Out:
#                         city  inspection_date  name  establishment_type  \
# business_id
# EBHzEtuOJz474NwRQFqJbg    15               15    15                  15
# R__NLOqjUlw8qf12KD-I5A    14               14    14                  14
# grzKamxEuXTZrTkiztLQGg    14               14    14                  14
# u0KWFEkp2KCaB0ebmvi4Kw    13               13    13                  13
# F-bdXFkJwwENiNpMTG2ntQ    13               13    13                  13
# F_oPMHJrH42R67xp5eKtQA    13               13    13                  13
# I6oxEn1HT41S2GPrDKPPvA    12               12    12                  12
# isYj0rlYyUv3bUd4ZChxlQ    12               12    12                  12
# OJLR2T3CgXQkUgFmqrkTwQ    12               12    12                  12
# yX4anPCzNGDQ-v8_uug2yg    12               12    12                  12
# 1FL3oE2mqq_EFAYPd1TWUg    12               12    12                  12
# IHCaTeKF5-qul1V8IZ834g    12               12    12                  12
# 3FekhBpUmAWXBCvXBhuqVQ    11               11    11                  11
# 7XQLq8mnPeO5Wjhx7EBajg    11               11    11                  11
# 13ngZbrJVhnngzhc-MlXYg    11               11    11                  11
# 1WE-vUAugCNBg7-Vg4HKBg    11               11    11                  11
# nu-DHeDtxnOW5vYj93dGPQ    11               11    11                  11
# JOoblYsQjFT-47tkt6om0A    11               11    11                  11
# sQFpfRs1Flcw3evCdI2wpA    11               11    11                  11
# JfbbFcJgj8Zfn9SjGDnBgQ    11               11    11                  11
#
#                         address  latitude  longitude  inspection_result  \
# business_id
# EBHzEtuOJz474NwRQFqJbg       15        15         15                 15
# R__NLOqjUlw8qf12KD-I5A       14        14         14                 14
# grzKamxEuXTZrTkiztLQGg       14        14         14                 14
# u0KWFEkp2KCaB0ebmvi4Kw       13        13         13                 13
# F-bdXFkJwwENiNpMTG2ntQ       13        13         13                 13
# F_oPMHJrH42R67xp5eKtQA       13        13         13                 13
# I6oxEn1HT41S2GPrDKPPvA       12        12         12                 12
# isYj0rlYyUv3bUd4ZChxlQ       12        12         12                 12
# OJLR2T3CgXQkUgFmqrkTwQ       12        12         12                 12
# yX4anPCzNGDQ-v8_uug2yg       12        12         12                 12
# 1FL3oE2mqq_EFAYPd1TWUg       12        12         12                 12
# IHCaTeKF5-qul1V8IZ834g       12        12         12                 12
# 3FekhBpUmAWXBCvXBhuqVQ       11        11         11                 11
# 7XQLq8mnPeO5Wjhx7EBajg       11        11         11                 11
# 13ngZbrJVhnngzhc-MlXYg       11        11         11                 11
# 1WE-vUAugCNBg7-Vg4HKBg       11        11         11                 11
# nu-DHeDtxnOW5vYj93dGPQ       11        11         11                 11
# JOoblYsQjFT-47tkt6om0A       11        11         11                 11
# sQFpfRs1Flcw3evCdI2wpA       11        11         11                 11
# JfbbFcJgj8Zfn9SjGDnBgQ       11        11         11                 11
#
#                         violations_desc  minor  crucial  significant  \
# business_id
# EBHzEtuOJz474NwRQFqJbg               15     15       15           15
# R__NLOqjUlw8qf12KD-I5A               14     14       14           14
# grzKamxEuXTZrTkiztLQGg               14     14       14           14
# u0KWFEkp2KCaB0ebmvi4Kw               13     13       13           13
# F-bdXFkJwwENiNpMTG2ntQ               13     13       13           13
# F_oPMHJrH42R67xp5eKtQA               13     13       13           13
# I6oxEn1HT41S2GPrDKPPvA               12     12       12           12
# isYj0rlYyUv3bUd4ZChxlQ               12     12       12           12
# OJLR2T3CgXQkUgFmqrkTwQ               12     12       12           12
# yX4anPCzNGDQ-v8_uug2yg               12     12       12           12
# 1FL3oE2mqq_EFAYPd1TWUg               12     12       12           12
# IHCaTeKF5-qul1V8IZ834g               12     12       12           12
# 3FekhBpUmAWXBCvXBhuqVQ               11     11       11           11
# 7XQLq8mnPeO5Wjhx7EBajg               11     11       11           11
# 13ngZbrJVhnngzhc-MlXYg               11     11       11           11
# 1WE-vUAugCNBg7-Vg4HKBg               11     11       11           11
# nu-DHeDtxnOW5vYj93dGPQ               11     11       11           11
# JOoblYsQjFT-47tkt6om0A               11     11       11           11
# sQFpfRs1Flcw3evCdI2wpA               11     11       11           11
# JfbbFcJgj8Zfn9SjGDnBgQ               11     11       11           11
#
#                         violations_desc
# business_id
# EBHzEtuOJz474NwRQFqJbg               15
# R__NLOqjUlw8qf12KD-I5A               14
# grzKamxEuXTZrTkiztLQGg               14
# u0KWFEkp2KCaB0ebmvi4Kw               13
# F-bdXFkJwwENiNpMTG2ntQ               13
# F_oPMHJrH42R67xp5eKtQA               13
# I6oxEn1HT41S2GPrDKPPvA               12
# isYj0rlYyUv3bUd4ZChxlQ               12
# OJLR2T3CgXQkUgFmqrkTwQ               12
# yX4anPCzNGDQ-v8_uug2yg               12
# 1FL3oE2mqq_EFAYPd1TWUg               12
# IHCaTeKF5-qul1V8IZ834g               12
# 3FekhBpUmAWXBCvXBhuqVQ               11
# 7XQLq8mnPeO5Wjhx7EBajg               11
# 13ngZbrJVhnngzhc-MlXYg               11
# 1WE-vUAugCNBg7-Vg4HKBg               11
# nu-DHeDtxnOW5vYj93dGPQ               11
# JOoblYsQjFT-47tkt6om0A               11
# sQFpfRs1Flcw3evCdI2wpA               11
# JfbbFcJgj8Zfn9SjGDnBgQ               11

# %%
matched_ord['year'] = pd.DatetimeIndex(matched_ord['inspection_date']).year

# %%
matched_ord.groupby(['year', 'business_id']).count()['city'].describe()
# Out:
# count    38269.000000
# mean         3.195955
# std          9.895729
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max        314.000000
# Name: city, dtype: float64

# %%
matched_ord.groupby(['year', 'business_id']).count()['city'].quantile([.1, .9,0.95])
# Out:
# 0.10    1.0
# 0.90    4.0
# 0.95    6.0
# Name: city, dtype: float64

# %%
matched_ord[matched_ord['business_id']=='EBHzEtuOJz474NwRQFqJbg']
# Out:
#                    business_id     city inspection_date  \
# 106761  EBHzEtuOJz474NwRQFqJbg  toronto      2017-11-13
# 106762  EBHzEtuOJz474NwRQFqJbg  toronto      2018-04-04
# 106763  EBHzEtuOJz474NwRQFqJbg  toronto      2018-06-04
# 106764  EBHzEtuOJz474NwRQFqJbg  toronto      2018-06-11
# 106765  EBHzEtuOJz474NwRQFqJbg  toronto      2018-06-15
# 106766  EBHzEtuOJz474NwRQFqJbg  toronto      2018-06-18
# 106767  EBHzEtuOJz474NwRQFqJbg  toronto      2018-09-18
# 106768  EBHzEtuOJz474NwRQFqJbg  toronto      2018-10-29
# 106769  EBHzEtuOJz474NwRQFqJbg  toronto      2018-11-08
# 106770  EBHzEtuOJz474NwRQFqJbg  toronto      2018-12-31
# 106771  EBHzEtuOJz474NwRQFqJbg  toronto      2019-01-02
# 106772  EBHzEtuOJz474NwRQFqJbg  toronto      2019-02-20
# 106773  EBHzEtuOJz474NwRQFqJbg  toronto      2019-05-27
# 106774  EBHzEtuOJz474NwRQFqJbg  toronto      2019-08-02
# 106775  EBHzEtuOJz474NwRQFqJbg  toronto      2019-09-23
#
#                              name establishment_type          address  \
# 106761  POPEYES LOUISIANA KITCHEN         Restaurant  1955 QUEEN ST E
# 106762  POPEYES LOUISIANA KITCHEN         Restaurant  1955 QUEEN ST E
# 106763  POPEYES LOUISIANA KITCHEN         Restaurant  1955 QUEEN ST E
# 106764  POPEYES LOUISIANA KITCHEN         Restaurant  1955 QUEEN ST E
# 106765  POPEYES LOUISIANA KITCHEN         Restaurant  1955 QUEEN ST E
# 106766  POPEYES LOUISIANA KITCHEN         Restaurant  1955 QUEEN ST E
# 106767  POPEYES LOUISIANA KITCHEN         Restaurant  1955 QUEEN ST E
# 106768  POPEYES LOUISIANA KITCHEN         Restaurant  1955 QUEEN ST E
# 106769  POPEYES LOUISIANA KITCHEN         Restaurant  1955 QUEEN ST E
# 106770  POPEYES LOUISIANA KITCHEN         Restaurant  1955 QUEEN ST E
# 106771  POPEYES LOUISIANA KITCHEN         Restaurant  1955 QUEEN ST E
# 106772  POPEYES LOUISIANA KITCHEN         Restaurant  1955 QUEEN ST E
# 106773  POPEYES LOUISIANA KITCHEN         Restaurant  1955 QUEEN ST E
# 106774  POPEYES LOUISIANA KITCHEN         Restaurant  1955 QUEEN ST E
# 106775  POPEYES LOUISIANA KITCHEN         Restaurant  1955 QUEEN ST E
#
#          latitude  longitude inspection_result  \
# 106761  43.669259 -79.302131              Pass
# 106762  43.669259 -79.302131              Pass
# 106763  43.669259 -79.302131  Conditional Pass
# 106764  43.669259 -79.302131  Conditional Pass
# 106765  43.669259 -79.302131  Conditional Pass
# 106766  43.669259 -79.302131              Pass
# 106767  43.669259 -79.302131              Pass
# 106768  43.669259 -79.302131  Conditional Pass
# 106769  43.669259 -79.302131              Pass
# 106770  43.669259 -79.302131  Conditional Pass
# 106771  43.669259 -79.302131              Pass
# 106772  43.669259 -79.302131              Pass
# 106773  43.669259 -79.302131              Pass
# 106774  43.669259 -79.302131              Pass
# 106775  43.669259 -79.302131              Pass
#
#                                           violations_desc  minor  crucial  \
# 106761  Fail to Ensure the Presence of the Holder of a...      2        2
# 106762   Operator fail to properly wash surfaces in rooms      1        1
# 106763  Fail to provide hot and cold water for hand wa...      6        6
# 106764  Operator fail to ensure food is not contaminat...      3        3
# 106765       Operator fail to properly remove solid waste      1        1
# 106766   Operator fail to properly wash surfaces in rooms      1        1
# 106767  FOOD PREMISE NOT MAINTAINED WITH FOOD HANDLING...      2        2
# 106768  FAIL TO ENSURE EQUIPMENT SURFACE SANITIZED AS ...      7        7
# 106769                                                         1        1
# 106770  FAIL TO REMOVE GARBAGE WHEN NECESSARY TO MAINT...      5        5
# 106771                                                         1        1
# 106772  THERMOMETER IN REFRIGERATION EQUIPMENT NOT EAS...      1        1
# 106773  FAIL TO ENSURE EQUIPMENT SURFACE SANITIZED AS ...      1        1
# 106774                                                         1        1
# 106775                                                         1        1
#
#         significant                                    violations_desc    year
# 106761            2  Fail to Ensure the Presence of the Holder of a...  2017.0
# 106762            1   Operator fail to properly wash surfaces in rooms  2018.0
# 106763            6  Fail to provide hot and cold water for hand wa...  2018.0
# 106764            3  Operator fail to ensure food is not contaminat...  2018.0
# 106765            1       Operator fail to properly remove solid waste  2018.0
# 106766            1   Operator fail to properly wash surfaces in rooms  2018.0
# 106767            2  FOOD PREMISE NOT MAINTAINED WITH FOOD HANDLING...  2018.0
# 106768            7  FAIL TO ENSURE EQUIPMENT SURFACE SANITIZED AS ...  2018.0
# 106769            1                                                     2018.0
# 106770            5  FAIL TO REMOVE GARBAGE WHEN NECESSARY TO MAINT...  2018.0
# 106771            1                                                     2019.0
# 106772            1  THERMOMETER IN REFRIGERATION EQUIPMENT NOT EAS...  2019.0
# 106773            1  FAIL TO ENSURE EQUIPMENT SURFACE SANITIZED AS ...  2019.0
# 106774            1                                                     2019.0
# 106775            1                                                     2019.0

# %%
matched_ord[matched_ord['business_id']=='EBHzEtuOJz474NwRQFqJbg'].groupby(['year', 'business_id']).count()['city']
# Out:
# year    business_id
# 2017.0  EBHzEtuOJz474NwRQFqJbg    1
# 2018.0  EBHzEtuOJz474NwRQFqJbg    9
# 2019.0  EBHzEtuOJz474NwRQFqJbg    5
# Name: city, dtype: int64
