# %%
import os
import sys
import csv
import pandas as pd
import psycopg2
from sqlalchemy import create_engine
from fuzzywuzzy import fuzz 
from fuzzywuzzy import process 

sys.path.append('../')
from envir import config

# %% [markdown]
# This notebook uses the csv file from running the script named: 'fuzzy_match_business_names.py'
#
#
# #### connect & load data

# %%
engine = create_engine('postgresql+psycopg2:///yelp_abcs')
con = engine.connect

# %%
yelp = pd.read_sql("select * from stag.yelp_academic_business where state in ('ON', 'NV');", con=engine )
vegas = pd.read_sql("select * from clean.clean_vegas_violations;", con=engine)
toronto = pd.read_sql("select * from clean.toronto_inspections_new_cleaned;", con=engine)

# %%
yelp2 = yelp.loc[yelp['categories'].str.contains("Restaurant")==True][['business_id',
                                                                       'name', 'address']].copy()

yelp2.reset_index(inplace=True)

# %%
yelp2[yelp2.business_id=='EBHzEtuOJz474NwRQFqJbg']
# Out:
#        index             business_id                       name  \
# 18159  55806  EBHzEtuOJz474NwRQFqJbg  Popeyes Louisiana Kitchen
#
#                    address
# 18159  1955 Queen Street E

# %% [markdown]
# #### prep for concat / append tables

# %%
len(toronto) + len(vegas)
# Out:
# 264386

# %%
vegas.drop(columns=['index'], inplace=True)

# %%
violations = vegas.append(toronto, ignore_index=True, sort=True)

# %% [markdown]
# #### get unique business names from violations

# %%
fuzz_match = pd.read_csv(config.shared+'fuzzy_biz_names80.csv')

# %%
fuzz_match[(fuzz_match.yelp_name_address == fuzz_match.violations_name_address) & (fuzz_match.match_score < 100)]
# Out:
# Empty DataFrame
# Columns: [yelp_name_address, violations_name_address, match_score]
# Index: []

# %%
fuzz_match[(fuzz_match.yelp_name_address != fuzz_match.violations_name_address) & (fuzz_match.match_score == 100)]
# Out:
#                             yelp_name_address  \
# 106    D-Spot Dessert Cafe 1060 The Queensway
# 121               Kimchi House 586 Bloor St W
# 129       Brass Taps Pizza Pub 934 College St
# 243               Pho Vietnam 1280 Kennedy Rd
# 250       Las Tapatias 6132 W Charleston Blvd
# ...                                       ...
# 30864          5 Spice Dining 2826 Markham Rd
# 30889        C&C Supermarket 888 Don Mills Rd
# 30965           Pumpernickel's 101 College St
# 30987    Peter Piper Pizza 6081 S Eastern Ave
# 31019     Kobi Korean Restaurant 710 Yonge St
#
#                         violations_name_address  match_score
# 106    D SPOT DESSERT CAFE 1060 THE QUEENSWAY          100.0
# 121                 KIMCHI HOUSE 586 BLOOR ST W        100.0
# 129        BRASS TAPS PIZZA PUB 934 COLLEGE ST         100.0
# 243                PHO VIETNAM 1280 KENNEDY RD         100.0
# 250         LAS TAPATIAS 6132 W Charleston Blvd        100.0
# ...                                         ...          ...
# 30864          5 SPICE DINING  2826 MARKHAM RD         100.0
# 30889      C & C SUPERMARKET  888 DON MILLS RD         100.0
# 30965            PUMPERNICKEL'S 101 COLLEGE ST         100.0
# 30987      PETER PIPER PIZZA 6081 S EASTERN Ave        100.0
# 31019      KOBI KOREAN RESTAURANT 710 YONGE ST         100.0
#
# [649 rows x 3 columns]

# %%
fuzz_match.groupby(['yelp_name_address',
                    'violations_name_address'],as_index=False).size().sort_values(ascending=False)
# Out:
# yelp_name_address                                       violations_name_address
# Burger King 3401 E Tropicana Ave                        Burger King #2701 3401 E Tropicana Ave                       2
# Ravi Soups 322 Adelaide Street W                        RAVI'S SOUP 322 ADELAIDE ST W                                2
# Baja Fresh 8780 W Charleston Blvd, Ste 100              Baja Fresh 8780 W Charleston Blvd                            2
# Carl's Jr. 4901 W Craig Rd                              CARL'S JR #7073 4901 W Craig Rd                              2
# Pizza Pizza 260 Church Street                           PIZZA PIZZA 260 CHURCH ST                                    2
#                                                                                                                     ..
# Popeyes Louisiana Kitchen 150 Park Lawn Road            POPEYES LOUISIANA KITCHEN 150 PARK LAWN RD                   1
# Popeyes Louisiana Kitchen 1525 Dundas Street E, Unit 4  POPEYES LOUISIANA KITCHEN 275 DUNDAS ST W                    1
# Popeyes Louisiana Kitchen 181 Eglinton Avenue E         POPEYES LOUISIANA KITCHEN 181 EGLINTON AVE E                 1
# Popeyes Louisiana Kitchen 1955 Queen Street E           POPEYES LOUISIANA KITCHEN 1955 QUEEN ST E                    1
# #1 Hawaiian Barbecue 5905 S Eastern Ave, Ste 105        CHINA DRAGON/#1 HAWAIIAN BARBEQUE 5905 S EASTERN Ave -105    1
# Length: 8424, dtype: int64

# %%
fuzz_match.sort_values(['violations_name_address','match_score'], ascending=False, inplace=True)

# %%
fuzz_match.drop_duplicates(['violations_name_address'], inplace=True)

# %%
yelp2
# Out:
#        index             business_id                                 name  \
# 0          0  QXAEGFB4oINsVuTFxEYKFQ           Emerald Chinese Restaurant
# 1          4  PZ-LZzSlhSe9utkQYU8pFg           Carluccio's Tivoli Gardens
# 2         11  tstimHoMcYbkSC4eBA1wEg  Maria's Mexican Restaurant & Bakery
# 3         15  NDuUMJfrWk52RA-H-OtrpA                       Bolt Fresh Bar
# 4         17  SP_YXIEwkFPPl_9anCYmpQ                The Steady Cafe & Bar
# ...      ...                     ...                                  ...
# 22615  69706  sVEE_Mp3EbWW1UIhfActVA                   The King's Kitchen
# 22616  69712  lo8WwqKogC-kz4toRvkdUQ                      KOKO! Share Bar
# 22617  69714  3HAPJH0Qoi8Ix6M9rUMfjg                          Indian Hero
# 22618  69716  oS0CnUbyv0GUoD3L8_3UPQ                         Thai Fantasy
# 22619  69718  h3QErqS3OZgLJ5Tb6-sLyQ                             Asia Hut
#
#                             address
# 0              30 Eglinton Avenue W
# 1      1775 E Tropicana Ave, Ste 29
# 2             6055 E Lake Mead Blvd
# 3               1170 Queen Street W
# 4               1051 Bloor Street W
# ...                             ...
# 22615          9275 Hwy 48, Unit 11
# 22616           81 Yorkville Avenue
# 22617               8920 Highway 50
# 22618              578 Yonge Street
# 22619              1450 Kingston Rd
#
# [22620 rows x 4 columns]

# %%
yelp2['yelp_name_address'] = yelp2['name'] + ' ' + yelp2['address']

# %%
yelp2.drop(columns=['name', 'address', 'index'], inplace=True)

# %%
violations['violations_name_address'] = violations['name'] + ' ' + violations['address']

# %%
fuzz_match.groupby(['violations_name_address'],as_index=False).size().sort_values(ascending=False)
# Out:
# violations_name_address
# iQ FOOD CO. 181 BAY ST                            1
# Gusto Pizza 1 BONIS AVE                           1
# HAMPTONS 440 S RAMPART Blvd 180                   1
# HAN BA TANG RESTAURANT 4862 YONGE ST              1
# HANA KOREA 45 BALDWIN ST                          1
#                                                  ..
# PTS GOLD 47 9050 W Post Rd                        1
# PUBLIC HOUSE @ LUXOR 3900 S LAS VEGAS Blvd        1
# PUBLICUS 1126 FREMONT St                          1
# PUCK N WINGS 5625 YONGE ST                        1
# #1 HAWAIIAN BARBECUE 7960 S RAINBOW Blvd 8000G    1
# Length: 7720, dtype: int64

# %%
matched = violations.merge(fuzz_match,
                           on='violations_name_address', how='inner').merge(yelp2,
                                                                              on='yelp_name_address', how='inner')

# %%
matched.columns
# Out:
# Index(['address', 'city', 'crucial', 'establishment_type', 'inspection_date',
#        'inspection_result', 'latitude', 'longitude', 'minor', 'name',
#        'significant', 'violations_desc', 'violations_name_address',
#        'yelp_name_address', 'match_score', 'business_id'],
#       dtype='object')

# %%
matched_ord = matched.reindex(columns=['business_id','city','inspection_date', 'name','establishment_type',
                                       'address','latitude', 'longitude','inspection_result',
                                       'violations_desc','minor','crucial','significant','violations_desc']).copy()

# %%
try:
    matched_ord.to_sql("violations_matched_yelp_id", engine, schema="clean")
except:
    print('table already exists')
# Out:
# table already exists

# %%
matched_ord.to_csv(config.shared+'violations_matched_yelp_id.csv')

# %%
len(violations)
# Out:
# 264386

# %%
len(matched_ord)
# Out:
# 122548

# %%
len(matched_ord)/len(violations)
# Out:
# 0.46351924837169894

# %%
matched_ord.groupby(by='city', as_index=False).agg({'business_id': pd.Series.nunique})
# Out:
#         city  business_id
# 0  Las Vegas         3420
# 1    toronto         4314

# %%
# compare to API
import requests, json
url='https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer %s' % config.yelpApi}
params = {'location':'Toronto'}
req = requests.get(url, params=params, headers=headers)
res_json = json.loads(req.text)

# %%
res_json['total']
# Out:
# 10300

# %%
matched_ord[matched_ord.city=='Las Vegas'].groupby('business_id').count().sort_values('inspection_date', ascending=False).head(20)
# Out:
#                         city  inspection_date  name  establishment_type  \
# business_id
# El4FC8jcawUVgw_0EIcbaQ  2812             2805  2812                2787
# Ou8pYS24azDWG0ru_vUcqg  2644             2633  2644                2604
# eAc9Vd6loOgRQolMXQt6FA  2600             2596  2600                2517
# xtYiHTmunjfCN2sUaQxBjA  1741             1737  1741                1652
# 3Gt3xskppi9jZuTrwrhLNg  1693             1692  1693                1676
# HoKXKkW8oC9q8XnjKLulRw  1664             1663  1664                1554
# RhEvP5flF6KoPriMHmVYGg  1494             1489  1494                1435
# iyoym9B8gU_YPXSb3m31LA  1265             1260  1265                1238
# VE5KGq9ztCztivwbmjNlTQ  1130             1130  1130                1086
# Kn23LDd740SBVJ7mum0fwg  1121             1119  1121                1108
# ebTvBxSStI9Vf5Tpux_X3Q  1105             1104  1105                1090
# ii8sAGBexBOJoYRFafF9XQ  1080             1078  1080                1079
# gFjHMjQXn5pbObxJupiuPA  1071             1063  1071                1071
# yQfiIg-HDflMzBKOfyTqQA  1015             1011  1015                1012
# 3cg4pKBL8DTFXCtZ5y9V4g  1016             1006  1016                 956
# qi7PnlfceCl3otbEUWz75w   957              955   957                 949
# qMOyKuyZpFH-Lmszd3Mn-A   902              899   902                 897
# BIBWGO_r_1znnlmLbp4Nxg   899              897   899                 878
# 4uiijOUDzc-DeIb2XcKW_A   833              832   833                 833
# NUpRBNSWuhRQ2tze3-A-Ng   827              824   827                 814
#
#                         address  latitude  longitude  inspection_result  \
# business_id
# El4FC8jcawUVgw_0EIcbaQ     2812      2812       2812               2805
# Ou8pYS24azDWG0ru_vUcqg     2644      2644       2644               2634
# eAc9Vd6loOgRQolMXQt6FA     2600      2600       2600               2596
# xtYiHTmunjfCN2sUaQxBjA     1741      1741       1741               1738
# 3Gt3xskppi9jZuTrwrhLNg     1693      1693       1693               1693
# HoKXKkW8oC9q8XnjKLulRw     1664      1664       1664               1663
# RhEvP5flF6KoPriMHmVYGg     1494      1494       1494               1492
# iyoym9B8gU_YPXSb3m31LA     1265      1265       1265               1264
# VE5KGq9ztCztivwbmjNlTQ     1130      1130       1130               1130
# Kn23LDd740SBVJ7mum0fwg     1121      1121       1121               1119
# ebTvBxSStI9Vf5Tpux_X3Q     1105      1105       1105               1104
# ii8sAGBexBOJoYRFafF9XQ     1080      1080       1080               1078
# gFjHMjQXn5pbObxJupiuPA     1071      1071       1071               1063
# yQfiIg-HDflMzBKOfyTqQA     1015      1015       1015               1015
# 3cg4pKBL8DTFXCtZ5y9V4g     1016      1016       1016               1008
# qi7PnlfceCl3otbEUWz75w      957       957        957                955
# qMOyKuyZpFH-Lmszd3Mn-A      902       902        902                899
# BIBWGO_r_1znnlmLbp4Nxg      899       899        899                897
# 4uiijOUDzc-DeIb2XcKW_A      833       833        833                832
# NUpRBNSWuhRQ2tze3-A-Ng      827       827        827                824
#
#                         violations_desc  minor  crucial  significant  \
# business_id
# El4FC8jcawUVgw_0EIcbaQ             2812   2812     2812         2812
# Ou8pYS24azDWG0ru_vUcqg             2644   2644     2644         2644
# eAc9Vd6loOgRQolMXQt6FA             2600   2600     2600         2600
# xtYiHTmunjfCN2sUaQxBjA             1741   1741     1741         1741
# 3Gt3xskppi9jZuTrwrhLNg             1693   1693     1693         1693
# HoKXKkW8oC9q8XnjKLulRw             1664   1664     1664         1664
# RhEvP5flF6KoPriMHmVYGg             1494   1494     1494         1494
# iyoym9B8gU_YPXSb3m31LA             1265   1265     1265         1265
# VE5KGq9ztCztivwbmjNlTQ             1130   1130     1130         1130
# Kn23LDd740SBVJ7mum0fwg             1121   1121     1121         1121
# ebTvBxSStI9Vf5Tpux_X3Q             1105   1105     1105         1105
# ii8sAGBexBOJoYRFafF9XQ             1080   1080     1080         1080
# gFjHMjQXn5pbObxJupiuPA             1071   1071     1071         1071
# yQfiIg-HDflMzBKOfyTqQA             1015   1015     1015         1015
# 3cg4pKBL8DTFXCtZ5y9V4g             1016   1016     1016         1016
# qi7PnlfceCl3otbEUWz75w              957    957      957          957
# qMOyKuyZpFH-Lmszd3Mn-A              902    902      902          902
# BIBWGO_r_1znnlmLbp4Nxg              899    899      899          899
# 4uiijOUDzc-DeIb2XcKW_A              833    833      833          833
# NUpRBNSWuhRQ2tze3-A-Ng              827    827      827          827
#
#                         violations_desc
# business_id
# El4FC8jcawUVgw_0EIcbaQ             2812
# Ou8pYS24azDWG0ru_vUcqg             2644
# eAc9Vd6loOgRQolMXQt6FA             2600
# xtYiHTmunjfCN2sUaQxBjA             1741
# 3Gt3xskppi9jZuTrwrhLNg             1693
# HoKXKkW8oC9q8XnjKLulRw             1664
# RhEvP5flF6KoPriMHmVYGg             1494
# iyoym9B8gU_YPXSb3m31LA             1265
# VE5KGq9ztCztivwbmjNlTQ             1130
# Kn23LDd740SBVJ7mum0fwg             1121
# ebTvBxSStI9Vf5Tpux_X3Q             1105
# ii8sAGBexBOJoYRFafF9XQ             1080
# gFjHMjQXn5pbObxJupiuPA             1071
# yQfiIg-HDflMzBKOfyTqQA             1015
# 3cg4pKBL8DTFXCtZ5y9V4g             1016
# qi7PnlfceCl3otbEUWz75w              957
# qMOyKuyZpFH-Lmszd3Mn-A              902
# BIBWGO_r_1znnlmLbp4Nxg              899
# 4uiijOUDzc-DeIb2XcKW_A              833
# NUpRBNSWuhRQ2tze3-A-Ng              827

# %%
matched_ord['year'] = pd.DatetimeIndex(matched_ord['inspection_date']).year

# %%
matched_ord.groupby(['year', 'business_id']).count()['city'].describe()
# Out:
# count    38269.000000
# mean         3.195955
# std          9.895729
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max        314.000000
# Name: city, dtype: float64

# %%
matched_ord.groupby(['year', 'business_id']).count()['city'].quantile([.1, .9,0.95])
# Out:
# 0.10    1.0
# 0.90    4.0
# 0.95    6.0
# Name: city, dtype: float64

# %%
matched_ord[matched_ord['business_id']=='Ou8pYS24azDWG0ru_vUcqg']
# Out:
#                  business_id       city      inspection_date  \
# 3351  Ou8pYS24azDWG0ru_vUcqg  Las Vegas  2013-01-10 12:00:00
# 3352  Ou8pYS24azDWG0ru_vUcqg  Las Vegas  2014-02-21 13:00:00
# 3353  Ou8pYS24azDWG0ru_vUcqg  Las Vegas  2015-02-17 10:20:00
# 3354  Ou8pYS24azDWG0ru_vUcqg  Las Vegas  2019-03-01 11:15:00
# 3355  Ou8pYS24azDWG0ru_vUcqg  Las Vegas  2007-04-09 15:25:00
# ...                      ...        ...                  ...
# 5990  Ou8pYS24azDWG0ru_vUcqg  Las Vegas                 None
# 5991  Ou8pYS24azDWG0ru_vUcqg  Las Vegas                 None
# 5992  Ou8pYS24azDWG0ru_vUcqg  Las Vegas  2019-08-19 11:30:00
# 5993  Ou8pYS24azDWG0ru_vUcqg  Las Vegas  2019-10-16 13:20:00
# 5994  Ou8pYS24azDWG0ru_vUcqg  Las Vegas                 None
#
#                                name establishment_type                address  \
# 3351  CAESARS PALACE HOTEL & CASINO             Buffet  3570 S Las Vegas Blvd
# 3352  CAESARS PALACE HOTEL & CASINO             Pantry  3570 S Las Vegas Blvd
# 3353  CAESARS PALACE HOTEL & CASINO             Pantry  3570 S Las Vegas Blvd
# 3354  CAESARS PALACE HOTEL & CASINO    Banquet Kitchen  3570 S Las Vegas Blvd
# 3355  CAESARS PALACE HOTEL & CASINO             Pantry  3570 S Las Vegas Blvd
# ...                             ...                ...                    ...
# 5990  CAESARS PALACE HOTEL & CASINO               None  3570 S Las Vegas Blvd
# 5991  CAESARS PALACE HOTEL & CASINO               None  3570 S Las Vegas Blvd
# 5992  CAESARS PALACE HOTEL & CASINO       Bar / Tavern  3570 S Las Vegas Blvd
# 5993  CAESARS PALACE HOTEL & CASINO    Special Kitchen  3570 S Las Vegas Blvd
# 5994  CAESARS PALACE HOTEL & CASINO         Restaurant  3570 S Las Vegas Blvd
#
#        latitude   longitude inspection_result  \
# 3351  36.116156 -115.175058         Compliant
# 3352  36.116156 -115.175058         Compliant
# 3353  36.116156 -115.175058         Compliant
# 3354  36.116156 -115.175058           A Grade
# 3355  36.116156 -115.175058         Compliant
# ...         ...         ...               ...
# 5990  36.116156 -115.175058              None
# 5991  36.116156 -115.175058              None
# 5992  36.116156 -115.175058           A Grade
# 5993  36.116156 -115.175058           A Grade
# 5994  36.116156 -115.175058              None
#
#                                         violations_desc  minor  crucial  \
# 3351                                                         0        0
# 3352                                                         0        0
# 3353                                                         0        0
# 3354                                                         0        0
# 3355  Non-food contact surfaces and/or cooking devic...      2        0
# ...                                                 ...    ...      ...
# 5990                                                         0        0
# 5991                                                         0        0
# 5992  Handwashing facilities adequate in number     ...      1        0
# 5993  Food protected from potential contamination by...      1        0
# 5994                                                         0        0
#
#       significant                                    violations_desc
# 3351            0
# 3352            0
# 3353            0
# 3354            0
# 3355            2  Non-food contact surfaces and/or cooking devic...
# ...           ...                                                ...
# 5990            0
# 5991            0
# 5992            2  Handwashing facilities adequate in number     ...
# 5993            2  Food protected from potential contamination by...
# 5994            0
#
# [2644 rows x 14 columns]

# %%
matched_ord[matched_ord['business_id']=='EBHzEtuOJz474NwRQFqJbg'].groupby(['year', 'business_id']).count()['city']
# Out:
# year    business_id
# 2017.0  EBHzEtuOJz474NwRQFqJbg    1
# 2018.0  EBHzEtuOJz474NwRQFqJbg    9
# 2019.0  EBHzEtuOJz474NwRQFqJbg    5
# Name: city, dtype: int64

# %%
# Out:
# 339
